# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# Which CSV & TSV files do we have available?

# %%
ls -lath ./data/*
# Out:
# -rw-r--r--  1 DAILYSPARK  staff    12M Dec  2 11:09 ./data/imdb.title.principals.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff    52K Dec  2 11:09 ./data/bom.movie_gross.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   150K Dec  2 11:09 ./data/tn.movie_budgets.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   487K Dec  2 11:09 ./data/rt.movie_info.tsv.gz
# -rw-r--r--  1 DAILYSPARK  staff   3.3M Dec  2 11:09 ./data/imdb.title.basics.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   3.2M Dec  2 11:09 ./data/rt.reviews.tsv.gz
# -rw-r--r--  1 DAILYSPARK  staff    17M Dec  2 11:09 ./data/imdb.name.basics.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   527K Dec  2 11:09 ./data/imdb.title.ratings.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   5.3M Dec  2 11:09 ./data/imdb.title.akas.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   808K Dec  2 11:09 ./data/tmdb.movies.csv.gz
# -rw-r--r--  1 DAILYSPARK  staff   1.8M Dec  2 11:09 ./data/imdb.title.crew.csv.gz

# %%
pwd
# Out:
# '/Users/DAILYSPARK/Code/projects/project1'

# %%
# read movie CSV & TSV files. Use latin1 encoding for 'rt.reviews.tsv.gz' to avoid errors
bom_movie_gross_df = pd.read_csv('./data/bom.movie_gross.csv.gz')
tn_budgets_df = pd.read_csv('./data/tn.movie_budgets.csv.gz')
rt_reviews_df = pd.read_csv('./data/rt.reviews.tsv.gz', sep='\t', encoding='latin1')
rt_movie_info_df = pd.read_csv('./data/rt.movie_info.tsv.gz', sep='\t')
imdb_ratings_df = pd.read_csv('./data/imdb.title.ratings.csv.gz')
imdb_crew_df = pd.read_csv('./data/imdb.title.crew.csv.gz')
imdb_title_basics_df = pd.read_csv('./data/imdb.title.basics.csv.gz')
imdb_akas_df = pd.read_csv('./data/imdb.title.akas.csv.gz')
imdb_principals_df = pd.read_csv('./data/imdb.title.principals.csv.gz')
imdb_name_basics_df = pd.read_csv('./data/imdb.name.basics.csv.gz')
tmdb_movies_df = pd.read_csv('./data/tmdb.movies.csv.gz')

# %%
# View bom_movie_gross_df sorted by domestic_gross from greatest to least
bom_movie_gross_df.sort_values('domestic_gross', ascending=False).head()
# Out:
#                              title studio  domestic_gross foreign_gross  year
# 1872  Star Wars: The Force Awakens     BV     936700000.0       1,131.6  2015
# 3080                 Black Panther     BV     700100000.0     646900000  2018
# 3079        Avengers: Infinity War     BV     678800000.0       1,369.5  2018
# 1873                Jurassic World   Uni.     652300000.0       1,019.4  2015
# 727          Marvel's The Avengers     BV     623400000.0     895500000  2012

# %%
# 3387 records in bom_movie_gross_df. 1350 foreign gross records missing. 5 studio records missing
bom_movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
# title             3387 non-null object
# studio            3382 non-null object
# domestic_gross    3359 non-null float64
# foreign_gross     2037 non-null object
# year              3387 non-null int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
# tn_budgets_df contains similar info to bom_movie_gross_df, but all records are non-null. 5782 rows
tn_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
# change production_budget, domestic_gross, worldwide_gross from strings to numbers
tn_budgets_df['production_budget'] = tn_budgets_df['production_budget'].apply(lambda x: x.replace('$', '').replace(',', '')).astype(float)
tn_budgets_df['domestic_gross'] = tn_budgets_df['domestic_gross'].apply(lambda x: x.replace('$', '').replace(',', '')).astype(float)
tn_budgets_df['worldwide_gross'] = tn_budgets_df['worldwide_gross'].apply(lambda x: x.replace('$', '').replace(',', '')).astype(float)

# %%
# convert release_date to datetime object
tn_budgets_df['release_date'] = pd.to_datetime(tn_budgets_df['release_date'])

# %%
# limit tn_budgets_df to 2010-2018 like other data sets - 2124 records
tn_budgets_2010_2018_df = tn_budgets_df[tn_budgets_df['release_date'].apply(lambda x: x.year >= 2010 and x.year <= 2018)]

# %%
tn_budgets_2010_2018_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2124 entries, 1 to 5780
# Data columns (total 6 columns):
# id                   2124 non-null int64
# release_date         2124 non-null datetime64[ns]
# movie                2124 non-null object
# production_budget    2124 non-null float64
# domestic_gross       2124 non-null float64
# worldwide_gross      2124 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 116.2+ KB

# %%
# All 5782 rows appear to contain complete info
tn_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null datetime64[ns]
# movie                5782 non-null object
# production_budget    5782 non-null float64
# domestic_gross       5782 non-null float64
# worldwide_gross      5782 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 271.2+ KB

# %%
# View tn_budgets_df sorted by worldwide_gross from greatest to least
tn_budgets_df.sort_values('worldwide_gross', ascending=False).head(10)
# Out:
#      id release_date                                          movie  \
# 0     1   2009-12-18                                         Avatar
# 42   43   1997-12-19                                        Titanic
# 5     6   2015-12-18           Star Wars Ep. VII: The Force Awakens
# 6     7   2018-04-27                         Avengers: Infinity War
# 33   34   2015-06-12                                 Jurassic World
# 66   67   2015-04-03                                      Furious 7
# 26   27   2012-05-04                                   The Avengers
# 3     4   2015-05-01                        Avengers: Age of Ultron
# 41   42   2018-02-16                                  Black Panther
# 260  61   2011-07-15  Harry Potter and the Deathly Hallows: Part II
#
#      production_budget  domestic_gross  worldwide_gross
# 0          425000000.0     760507625.0     2.776345e+09
# 42         200000000.0     659363944.0     2.208208e+09
# 5          306000000.0     936662225.0     2.053311e+09
# 6          300000000.0     678815482.0     2.048134e+09
# 33         215000000.0     652270625.0     1.648855e+09
# 66         190000000.0     353007020.0     1.518723e+09
# 26         225000000.0     623279547.0     1.517936e+09
# 3          330600000.0     459005868.0     1.403014e+09
# 41         200000000.0     700059566.0     1.348258e+09
# 260        125000000.0     381193157.0     1.341693e+09

# %%
# Scatterplot for production_budget vs domestic_gross 
ax = tn_budgets_2010_2018_df.plot(kind='scatter', x='production_budget', y='domestic_gross', color='orange')

ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# Scatterplot for production_budget vs worldwide_gross 
ax = tn_budgets_2010_2018_df.plot(kind='scatter', x='production_budget', y='worldwide_gross')
ax.get_xaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
sns.set(color_codes=True)
sns.regplot(x='production_budget', y='domestic_gross', data=tn_budgets_2010_2018_df);

# %%
sns.regplot(x='production_budget', y='worldwide_gross', data=tn_budgets_2010_2018_df)

# %%
imdb_title_basics_df.loc[imdb_title_basics_df['primary_title'] == 'Avatar']
# Out:
#           tconst primary_title original_title  start_year  runtime_minutes  \
# 17060  tt1775309        Avatar          Abatâ        2011             93.0
#
#        genres
# 17060  Horror

# %%
# Join tn_budgets_df to imdb_title_basics_df to gain to genre information
joined_df = tn_budgets_df.join(imdb_title_basics_df.set_index('primary_title'), on='movie', how='inner')

# %%
joined_df = joined_df.sort_values('worldwide_gross', ascending=False)

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 5780
# Data columns (total 11 columns):
# id                   3815 non-null int64
# release_date         3815 non-null datetime64[ns]
# movie                3815 non-null object
# production_budget    3815 non-null float64
# domestic_gross       3815 non-null float64
# worldwide_gross      3815 non-null float64
# tconst               3815 non-null object
# original_title       3814 non-null object
# start_year           3815 non-null int64
# runtime_minutes      3328 non-null float64
# genres               3743 non-null object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(4)
# memory usage: 357.7+ KB

# %%
# Observe most common genres among the highest grossing films
joined_df.head(50)
# Out:
#      id release_date                                        movie  \
# 0     1   2009-12-18                                       Avatar
# 42   43   1997-12-19                                      Titanic
# 42   43   1997-12-19                                      Titanic
# 6     7   2018-04-27                       Avengers: Infinity War
# 33   34   2015-06-12                               Jurassic World
# 66   67   2015-04-03                                    Furious 7
# 26   27   2012-05-04                                 The Avengers
# 3     4   2015-05-01                      Avengers: Age of Ultron
# 41   42   2018-02-16                                Black Panther
# 112  13   2018-06-22               Jurassic World: Fallen Kingdom
# 155  56   2013-11-22                                       Frozen
# 155  56   2013-11-22                                       Frozen
# 155  56   2013-11-22                                       Frozen
# 134  35   2017-03-17                         Beauty and the Beast
# 134  35   2017-03-17                         Beauty and the Beast
# 134  35   2017-03-17                         Beauty and the Beast
# 43   44   2018-06-15                                Incredibles 2
# 22   23   2017-04-14                      The Fate of the Furious
# 47   48   2013-05-03                                   Iron Man 3
# 672  73   2015-07-10                                      Minions
# 135  36   2018-12-21                                      Aquaman
# 16   17   2016-05-06                   Captain America: Civil War
# 63   64   2011-06-29               Transformers: Dark of the Moon
# 95   96   2019-03-08                               Captain Marvel
# 51   52   2012-11-08                                      Skyfall
# 36   37   2014-06-27              Transformers: Age of Extinction
# 10   11   2012-07-20                        The Dark Knight Rises
# 46   47   2010-06-18                                  Toy Story 3
# 44   45   2016-12-16                 Rogue One: A Star Wars Story
# 1     2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 629  30   2017-06-30                              Despicable Me 3
# 50   51   2010-03-05                          Alice in Wonderland
# 50   51   2010-03-05                          Alice in Wonderland
# 50   51   2010-03-05                          Alice in Wonderland
# 45   46   2016-06-17                                 Finding Dory
# 156  57   2016-03-04                                     Zootopia
# 18   19   2012-12-14            The Hobbit: An Unexpected Journey
# 608   9   1994-06-15                                The Lion King
# 621  22   2013-07-03                              Despicable Me 2
# 437  38   2017-12-20               Jumanji: Welcome to the Jungle
# 96   97   2016-04-15                              The Jungle Book
# 96   97   2016-04-15                              The Jungle Book
# 20   21   2013-12-13          The Hobbit: The Desolation of Smaug
# 21   22   2014-12-17    The Hobbit: The Battle of the Five Armies
# 983  84   2018-11-02                            Bohemian Rhapsody
# 625  26   2016-07-08                      The Secret Life of Pets
# 98   99   2017-07-07                       Spider-Man: Homecoming
# 413  14   2012-07-13                   Ice Age: Continental Drift
# 9    10   2015-11-06                                      Spectre
# 17   18   2016-03-25           Batman v Superman: Dawn of Justice
#
#      production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000.0     760507625.0     2.776345e+09  tt1775309
# 42         200000000.0     659363944.0     2.208208e+09  tt8852130
# 42         200000000.0     659363944.0     2.208208e+09  tt2495766
# 6          300000000.0     678815482.0     2.048134e+09  tt4154756
# 33         215000000.0     652270625.0     1.648855e+09  tt0369610
# 66         190000000.0     353007020.0     1.518723e+09  tt2820852
# 26         225000000.0     623279547.0     1.517936e+09  tt0848228
# 3          330600000.0     459005868.0     1.403014e+09  tt2395427
# 41         200000000.0     700059566.0     1.348258e+09  tt1825683
# 112        170000000.0     417719760.0     1.305773e+09  tt4881806
# 155        150000000.0     400738009.0     1.272470e+09  tt2294629
# 155        150000000.0     400738009.0     1.272470e+09  tt1611845
# 155        150000000.0     400738009.0     1.272470e+09  tt1323045
# 134        160000000.0     504014165.0     1.259200e+09  tt2771200
# 134        160000000.0     504014165.0     1.259200e+09  tt2316801
# 134        160000000.0     504014165.0     1.259200e+09  tt9173998
# 43         200000000.0     608581744.0     1.242521e+09  tt3606756
# 22         250000000.0     225764765.0     1.234846e+09  tt4630562
# 47         200000000.0     408992272.0     1.215392e+09  tt1300854
# 672         74000000.0     336045770.0     1.160336e+09  tt2293640
# 135        160000000.0     335061807.0     1.146895e+09  tt1477834
# 16         250000000.0     408084349.0     1.140069e+09  tt3498820
# 63         195000000.0     352390543.0     1.123791e+09  tt1399103
# 95         175000000.0     426525952.0     1.123062e+09  tt4154664
# 51         200000000.0     304360277.0     1.110527e+09  tt1074638
# 36         210000000.0     245439076.0     1.104039e+09  tt2109248
# 10         275000000.0     448139099.0     1.084439e+09  tt1345836
# 46         200000000.0     415004880.0     1.068880e+09  tt0435761
# 44         200000000.0     532177324.0     1.049103e+09  tt3748528
# 1          410600000.0     241063875.0     1.045664e+09  tt1298650
# 629         75000000.0     264624300.0     1.034728e+09  tt3469046
# 50         200000000.0     334191110.0     1.025491e+09  tt2049386
# 50         200000000.0     334191110.0     1.025491e+09  tt1014759
# 50         200000000.0     334191110.0     1.025491e+09  tt1926979
# 45         200000000.0     486295561.0     1.021215e+09  tt2277860
# 156        150000000.0     341268248.0     1.019430e+09  tt2948356
# 18         250000000.0     303003568.0     1.017004e+09  tt0903624
# 608         79300000.0     421785283.0     9.862149e+08  tt6105098
# 621         76000000.0     368065385.0     9.752168e+08  tt1690953
# 437         90000000.0     404508916.0     9.644962e+08  tt2283362
# 96         175000000.0     364001123.0     9.628545e+08  tt2226178
# 96         175000000.0     364001123.0     9.628545e+08  tt3040964
# 20         250000000.0     258366855.0     9.603669e+08  tt1170358
# 21         250000000.0     255119788.0     9.455776e+08  tt2310332
# 983         55000000.0     216303339.0     8.949853e+08  tt1727824
# 625         75000000.0     368384330.0     8.867505e+08  tt2709768
# 98         175000000.0     334201140.0     8.801664e+08  tt2250912
# 413         95000000.0     161321843.0     8.797651e+08  tt1667889
# 9          300000000.0     200074175.0     8.796209e+08  tt2379713
# 17         250000000.0     330360194.0     8.675003e+08  tt2975590
#
#                                   original_title  start_year  runtime_minutes  \
# 0                                          Abatâ        2011             93.0
# 42                                       Titanic        2018            115.0
# 42                                       Titanic        2012              NaN
# 6                         Avengers: Infinity War        2018            149.0
# 33                                Jurassic World        2015            124.0
# 66                                 Furious Seven        2015            137.0
# 26                                  The Avengers        2012            143.0
# 3                        Avengers: Age of Ultron        2015            141.0
# 41                                 Black Panther        2018            134.0
# 112               Jurassic World: Fallen Kingdom        2018            128.0
# 155                                       Frozen        2013            102.0
# 155                          Wai nei chung ching        2010             92.0
# 155                                       Frozen        2010             93.0
# 134                         Beauty and the Beast        2017            129.0
# 134                          La belle et la bête        2014            112.0
# 134                         Beauty and the Beast        2018             60.0
# 43                                 Incredibles 2        2018            118.0
# 22                       The Fate of the Furious        2017            136.0
# 47                                Iron Man Three        2013            130.0
# 672                                      Minions        2015             91.0
# 135                                      Aquaman        2018            143.0
# 16                    Captain America: Civil War        2016            147.0
# 63                Transformers: Dark of the Moon        2011            154.0
# 95                                Captain Marvel        2019            123.0
# 51                                       Skyfall        2012            143.0
# 36               Transformers: Age of Extinction        2014            165.0
# 10                         The Dark Knight Rises        2012            164.0
# 46                                   Toy Story 3        2010            103.0
# 44                                     Rogue One        2016            133.0
# 1    Pirates of the Caribbean: On Stranger Tides        2011            136.0
# 629                              Despicable Me 3        2017             89.0
# 50                           Alice in Wonderland        2010             99.0
# 50                           Alice in Wonderland        2010            108.0
# 50                           Alice in Wonderland        2011             48.0
# 45                                  Finding Dory        2016             97.0
# 156                                     Zootopia        2016            108.0
# 18             The Hobbit: An Unexpected Journey        2012            169.0
# 608                                The Lion King        2019              NaN
# 621                              Despicable Me 2        2013             98.0
# 437               Jumanji: Welcome to the Jungle        2017            119.0
# 96                               The Jungle Book        2014             64.0
# 96                               The Jungle Book        2016            106.0
# 20           The Hobbit: The Desolation of Smaug        2013            161.0
# 21     The Hobbit: The Battle of the Five Armies        2014            144.0
# 983                            Bohemian Rhapsody        2018            134.0
# 625                      The Secret Life of Pets        2016             87.0
# 98                        Spider-Man: Homecoming        2017            133.0
# 413                   Ice Age: Continental Drift        2012             88.0
# 9                                        Spectre        2015            148.0
# 17            Batman v Superman: Dawn of Justice        2016            151.0
#
#                          genres
# 0                        Horror
# 42                       Family
# 42                    Adventure
# 6       Action,Adventure,Sci-Fi
# 33      Action,Adventure,Sci-Fi
# 66        Action,Crime,Thriller
# 26      Action,Adventure,Sci-Fi
# 3       Action,Adventure,Sci-Fi
# 41      Action,Adventure,Sci-Fi
# 112     Action,Adventure,Sci-Fi
# 155  Adventure,Animation,Comedy
# 155             Fantasy,Romance
# 155       Adventure,Drama,Sport
# 134      Family,Fantasy,Musical
# 134       Drama,Fantasy,Romance
# 134      Family,Fantasy,Musical
# 43   Action,Adventure,Animation
# 22        Action,Crime,Thriller
# 47      Action,Adventure,Sci-Fi
# 672  Adventure,Animation,Comedy
# 135    Action,Adventure,Fantasy
# 16      Action,Adventure,Sci-Fi
# 63      Action,Adventure,Sci-Fi
# 95      Action,Adventure,Sci-Fi
# 51    Action,Adventure,Thriller
# 36      Action,Adventure,Sci-Fi
# 10              Action,Thriller
# 46   Adventure,Animation,Comedy
# 44      Action,Adventure,Sci-Fi
# 1      Action,Adventure,Fantasy
# 629  Adventure,Animation,Comedy
# 50              Fantasy,Musical
# 50     Adventure,Family,Fantasy
# 50                  Documentary
# 45   Adventure,Animation,Comedy
# 156  Adventure,Animation,Comedy
# 18     Adventure,Family,Fantasy
# 608   Adventure,Animation,Drama
# 621  Adventure,Animation,Comedy
# 437     Action,Adventure,Comedy
# 96                    Animation
# 96       Adventure,Drama,Family
# 20            Adventure,Fantasy
# 21            Adventure,Fantasy
# 983       Biography,Drama,Music
# 625  Adventure,Animation,Comedy
# 98      Action,Adventure,Sci-Fi
# 413  Adventure,Animation,Comedy
# 9     Action,Adventure,Thriller
# 17     Action,Adventure,Fantasy

# %%
# Group our joined_df by genres and sum to get an idea of the highest grossing categories
joined_df.groupby('genres').sum()
# Out:
#                               id  production_budget  domestic_gross  \
# genres
# Action                      2188       1.530850e+09    1.270274e+09
# Action,Adventure             372       3.221720e+08    3.362977e+08
# Action,Adventure,Animation   781       1.957500e+09    2.664329e+09
# Action,Adventure,Biography   127       3.550000e+08    2.835859e+08
# Action,Adventure,Comedy     1617       2.657000e+09    3.680969e+09
# ...                          ...                ...             ...
# Sci-Fi,Thriller              500       1.430200e+08    2.086422e+08
# Sport                         94       9.200000e+07    4.365345e+07
# Thriller                    3979       2.099791e+09    2.046346e+09
# War                          249       1.600000e+08    2.074801e+08
# Western                      401       1.087500e+08    7.898605e+07
#
#                             worldwide_gross  start_year  runtime_minutes
# genres
# Action                         2.895306e+09       92669           1546.0
# Action,Adventure               7.663899e+08       12098            220.0
# Action,Adventure,Animation     7.435879e+09       34239           1705.0
# Action,Adventure,Biography     9.404109e+08       10078            646.0
# Action,Adventure,Comedy        9.818506e+09       66502           3460.0
# ...                                     ...         ...              ...
# Sci-Fi,Thriller                3.415280e+08       16129            584.0
# Sport                          8.408840e+07        6045            114.0
# Thriller                       4.587840e+09      163159           4917.0
# War                            4.536727e+08        8054            247.0
# Western                        8.944078e+07       16143            151.0
#
# [345 rows x 6 columns]

# %%
# Put top 500 worldwide grossing movies into their own df
top500_df = joined_df.head(500)
top500_df.head(30)
# Out:
#      id release_date                                        movie  \
# 0     1   2009-12-18                                       Avatar
# 42   43   1997-12-19                                      Titanic
# 42   43   1997-12-19                                      Titanic
# 6     7   2018-04-27                       Avengers: Infinity War
# 33   34   2015-06-12                               Jurassic World
# 66   67   2015-04-03                                    Furious 7
# 26   27   2012-05-04                                 The Avengers
# 3     4   2015-05-01                      Avengers: Age of Ultron
# 41   42   2018-02-16                                Black Panther
# 112  13   2018-06-22               Jurassic World: Fallen Kingdom
# 155  56   2013-11-22                                       Frozen
# 155  56   2013-11-22                                       Frozen
# 155  56   2013-11-22                                       Frozen
# 134  35   2017-03-17                         Beauty and the Beast
# 134  35   2017-03-17                         Beauty and the Beast
# 134  35   2017-03-17                         Beauty and the Beast
# 43   44   2018-06-15                                Incredibles 2
# 22   23   2017-04-14                      The Fate of the Furious
# 47   48   2013-05-03                                   Iron Man 3
# 672  73   2015-07-10                                      Minions
# 135  36   2018-12-21                                      Aquaman
# 16   17   2016-05-06                   Captain America: Civil War
# 63   64   2011-06-29               Transformers: Dark of the Moon
# 95   96   2019-03-08                               Captain Marvel
# 51   52   2012-11-08                                      Skyfall
# 36   37   2014-06-27              Transformers: Age of Extinction
# 10   11   2012-07-20                        The Dark Knight Rises
# 46   47   2010-06-18                                  Toy Story 3
# 44   45   2016-12-16                 Rogue One: A Star Wars Story
# 1     2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
#
#      production_budget  domestic_gross  worldwide_gross     tconst  \
# 0          425000000.0     760507625.0     2.776345e+09  tt1775309
# 42         200000000.0     659363944.0     2.208208e+09  tt2495766
# 42         200000000.0     659363944.0     2.208208e+09  tt8852130
# 6          300000000.0     678815482.0     2.048134e+09  tt4154756
# 33         215000000.0     652270625.0     1.648855e+09  tt0369610
# 66         190000000.0     353007020.0     1.518723e+09  tt2820852
# 26         225000000.0     623279547.0     1.517936e+09  tt0848228
# 3          330600000.0     459005868.0     1.403014e+09  tt2395427
# 41         200000000.0     700059566.0     1.348258e+09  tt1825683
# 112        170000000.0     417719760.0     1.305773e+09  tt4881806
# 155        150000000.0     400738009.0     1.272470e+09  tt2294629
# 155        150000000.0     400738009.0     1.272470e+09  tt1611845
# 155        150000000.0     400738009.0     1.272470e+09  tt1323045
# 134        160000000.0     504014165.0     1.259200e+09  tt2771200
# 134        160000000.0     504014165.0     1.259200e+09  tt2316801
# 134        160000000.0     504014165.0     1.259200e+09  tt9173998
# 43         200000000.0     608581744.0     1.242521e+09  tt3606756
# 22         250000000.0     225764765.0     1.234846e+09  tt4630562
# 47         200000000.0     408992272.0     1.215392e+09  tt1300854
# 672         74000000.0     336045770.0     1.160336e+09  tt2293640
# 135        160000000.0     335061807.0     1.146895e+09  tt1477834
# 16         250000000.0     408084349.0     1.140069e+09  tt3498820
# 63         195000000.0     352390543.0     1.123791e+09  tt1399103
# 95         175000000.0     426525952.0     1.123062e+09  tt4154664
# 51         200000000.0     304360277.0     1.110527e+09  tt1074638
# 36         210000000.0     245439076.0     1.104039e+09  tt2109248
# 10         275000000.0     448139099.0     1.084439e+09  tt1345836
# 46         200000000.0     415004880.0     1.068880e+09  tt0435761
# 44         200000000.0     532177324.0     1.049103e+09  tt3748528
# 1          410600000.0     241063875.0     1.045664e+09  tt1298650
#
#                                   original_title  start_year  runtime_minutes  \
# 0                                          Abatâ        2011             93.0
# 42                                       Titanic        2012              NaN
# 42                                       Titanic        2018            115.0
# 6                         Avengers: Infinity War        2018            149.0
# 33                                Jurassic World        2015            124.0
# 66                                 Furious Seven        2015            137.0
# 26                                  The Avengers        2012            143.0
# 3                        Avengers: Age of Ultron        2015            141.0
# 41                                 Black Panther        2018            134.0
# 112               Jurassic World: Fallen Kingdom        2018            128.0
# 155                                       Frozen        2013            102.0
# 155                          Wai nei chung ching        2010             92.0
# 155                                       Frozen        2010             93.0
# 134                         Beauty and the Beast        2017            129.0
# 134                          La belle et la bête        2014            112.0
# 134                         Beauty and the Beast        2018             60.0
# 43                                 Incredibles 2        2018            118.0
# 22                       The Fate of the Furious        2017            136.0
# 47                                Iron Man Three        2013            130.0
# 672                                      Minions        2015             91.0
# 135                                      Aquaman        2018            143.0
# 16                    Captain America: Civil War        2016            147.0
# 63                Transformers: Dark of the Moon        2011            154.0
# 95                                Captain Marvel        2019            123.0
# 51                                       Skyfall        2012            143.0
# 36               Transformers: Age of Extinction        2014            165.0
# 10                         The Dark Knight Rises        2012            164.0
# 46                                   Toy Story 3        2010            103.0
# 44                                     Rogue One        2016            133.0
# 1    Pirates of the Caribbean: On Stranger Tides        2011            136.0
#
#                          genres
# 0                        Horror
# 42                    Adventure
# 42                       Family
# 6       Action,Adventure,Sci-Fi
# 33      Action,Adventure,Sci-Fi
# 66        Action,Crime,Thriller
# 26      Action,Adventure,Sci-Fi
# 3       Action,Adventure,Sci-Fi
# 41      Action,Adventure,Sci-Fi
# 112     Action,Adventure,Sci-Fi
# 155  Adventure,Animation,Comedy
# 155             Fantasy,Romance
# 155       Adventure,Drama,Sport
# 134      Family,Fantasy,Musical
# 134       Drama,Fantasy,Romance
# 134      Family,Fantasy,Musical
# 43   Action,Adventure,Animation
# 22        Action,Crime,Thriller
# 47      Action,Adventure,Sci-Fi
# 672  Adventure,Animation,Comedy
# 135    Action,Adventure,Fantasy
# 16      Action,Adventure,Sci-Fi
# 63      Action,Adventure,Sci-Fi
# 95      Action,Adventure,Sci-Fi
# 51    Action,Adventure,Thriller
# 36      Action,Adventure,Sci-Fi
# 10              Action,Thriller
# 46   Adventure,Animation,Comedy
# 44      Action,Adventure,Sci-Fi
# 1      Action,Adventure,Fantasy

# %%
# Attempted to sort rt_movie_info_df by box_office, but it's a string value
rt_movie_info_df.sort_values('box_office', ascending=False).head()
# Out:
#         id                                           synopsis rating  \
# 16      23  A fictional film set in the alluring world of ...      R
# 1510  1944  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 207    274  Natalie Portman stars in this western concerni...      R
# 1469  1890  A misplaced sausage and his savory friends emb...      R
# 1323  1711  Directed by Garry Marshall, The Princess Diari...      G
#
#                                                   genre  \
# 16                                                Drama
# 1510  Action and Adventure|Comedy|Science Fiction an...
# 207                  Action and Adventure|Drama|Western
# 1469                                   Animation|Comedy
# 1323                             Comedy|Kids and Family
#
#                         director  \
# 16                           NaN
# 1510               Michel Gondry
# 207                          NaN
# 1469  Conrad Vernon|Greg Tiernan
# 1323              Garry Marshall
#
#                                                  writer  theater_date  \
# 16                                                  NaN  Dec 20, 2013
# 1510                           Evan Goldberg|Seth Rogen  Jan 14, 2011
# 207                                                 NaN  Jan 29, 2016
# 1469  Kyle Hunter|Ariel Shaffir|Seth Rogen|Evan Gold...  Aug 12, 2016
# 1323                                      Shonda Rhimes  Aug 11, 2004
#
#           dvd_date currency  box_office      runtime         studio
# 16    Mar 18, 2014        $  99,165,609  129 minutes  Sony Pictures
# 1510   May 3, 2011        $  98,000,000  119 minutes  Sony Pictures
# 207   Apr 26, 2016        $     976,847   97 minutes            NaN
# 1469   Nov 8, 2016        $  97,661,826   89 minutes  Sony Pictures
# 1323  Dec 14, 2004        $  95,111,012  113 minutes            NaN

# %%
# 1560 rows... a lot of missing values for box_office, studio
rt_movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
# id              1560 non-null int64
# synopsis        1498 non-null object
# rating          1557 non-null object
# genre           1552 non-null object
# director        1361 non-null object
# writer          1111 non-null object
# theater_date    1201 non-null object
# dvd_date        1201 non-null object
# currency        340 non-null object
# box_office      340 non-null object
# runtime         1530 non-null object
# studio          494 non-null object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
rt_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
imdb_ratings_df.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
# Remove unneccesary index column 'Unnamed: 0'
tmdb_movies_df = tmdb_movies_df.drop(columns='Unnamed: 0')

# %%
# Perhaps the genre, popularity, vote_average, vote_count columns of tmdb_movies_df may be useful to us
tmdb_movies_df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
# tmdb_movies_df contains 26517 records. All of them appear to be complete (allegedly)
tmdb_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 9 columns):
# genre_ids            26517 non-null object
# id                   26517 non-null int64
# original_language    26517 non-null object
# original_title       26517 non-null object
# popularity           26517 non-null float64
# release_date         26517 non-null object
# title                26517 non-null object
# vote_average         26517 non-null float64
# vote_count           26517 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.8+ MB

# %%
# imdb_crew_df will be useful for telling us if a certain set of directors/writers will help our cause
imdb_crew_df.head()
# Out:
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
# imdb_titles_df may be useful telling us which genres tend to succeed the most
imdb_title_basics_df.head()
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
imdb_title_basics_df['genres'].value_counts().head(25)
# Out:
# Documentary                      32185
# Drama                            21486
# Comedy                            9177
# Horror                            4372
# Comedy,Drama                      3519
# Thriller                          3046
# Action                            2219
# Biography,Documentary             2115
# Drama,Romance                     2079
# Comedy,Drama,Romance              1558
# Documentary,Drama                 1554
# Comedy,Romance                    1507
# Romance                           1454
# Documentary,Music                 1365
# Drama,Thriller                    1335
# Documentary,History               1289
# Horror,Thriller                   1253
# Biography,Documentary,History     1230
# Biography,Documentary,Drama       1028
# Family                             939
# Animation                          828
# Drama,Family                       784
# Action,Crime,Drama                 727
# Comedy,Horror                      724
# Crime,Drama                        723
# Name: genres, dtype: int64

# %%
imdb_title_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
# tconst             146144 non-null object
# primary_title      146144 non-null object
# original_title     146123 non-null object
# start_year         146144 non-null int64
# runtime_minutes    114405 non-null float64
# genres             140736 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
# We probably don't need imdb_akas for now
imdb_akas_df.head()
# Out:
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
# imdb_principals_df may be useful for telling us if a certain set of directors/writers will help our cause
imdb_principals_df.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
# imdb_name_basics_df will allow us to pair the rest of our data with actual names
imdb_name_basics_df.head()
# Out:
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256
